# %% [markdown]
# ## 3. Robintrack - some analysis on users/tickers

# %%
# Import libraries and dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from dotenv import load_dotenv

#import numpy as np
#from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ### The objective is to read al the CVS files for all tickers and select (2020 - August) those above a certain number of users
# #### min_users = 0 will select all tickers

# %%
# This function read the csvfile into a datframe and gets the number of users for tickers with number of users bigger than a given target (min_users)

def read_data(raw_csv, min_users):
    
    # Read in csv 
    try:
        df_new_csv = pd.read_csv (raw_csv)  

    except Exception as err:
        print(f'Other error occurred: {err}')  
        return
    else:
        print('.', end = '')

    if df_new_csv.iloc[-1,-1] > min_users:
        print (f'\nticker: {raw_csv}, number of users = {df_new_csv.iloc[-1,-1]}') 
        return df_new_csv.iloc[-1,-1]

# %%
# function to get ticker's name from the string 
def string_cleaning(string):
    for index, letter in enumerate(string): 
        if letter == '/': ind = int(index)

    return string[ind+1:-4]

# %% [markdown]
# ### This main scrip sets the target of users and select all csv in all folders to be analyzed

# %%
# Citation: https://pandasninja.com/2019/04/how-to-read-lots-of-csv-files-easily-into-pandas/


# Create and empty DataFrame for most popular tickers 
df_popularity = pd.DataFrame()
min_users = 0
total_num_csv = 0

raw_folders = os.listdir('../data/rawdata_robin_all')
for folder in raw_folders:
    raw_csvs = os.listdir(f'../data/rawdata_robin_all/{folder}')
    for raw_csv in raw_csvs:
        raw_csv = f'../data/rawdata_robin_all/{folder}/{raw_csv}'
        number_users = read_data(raw_csv, min_users)
        total_num_csv += 1
        if number_users:
            ticker_symbol = string_cleaning(raw_csv)
            df_popularity = df_popularity.append({'ticker' : ticker_symbol, 'users' : number_users}, ignore_index = True) 

print ('\n\nend of dir loop')
print (f'\n total number of csv files (tickers) = {total_num_csv}')
# Out:
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RIV.csv, number of users = 395
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ANTE.csv, number of users = 930
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CSCO.csv, number of users = 67782
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PRI.csv, number of users = 1131
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SLIM.csv, number of users = 111
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BIOS.csv, number of users = 566
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NZF.csv, number of users = 247
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CSUAY.csv, number of users = 304
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HLNE.csv, number of users = 116
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MQBKY.csv, number of users = 68
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UNT.csv, number of users = 10548
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXB.csv, number of users = 79
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HUBS.csv, number of users = 4838
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GPL.csv, number of users = 7430
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSM.csv, number of users = 5
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ZURVY.csv, number of users = 233
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SBGI.csv, number of users = 1451
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UFCS.csv, number of users = 87
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TEAF.csv, number of users = 59
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PWCDF.csv, number of users = 208
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RJZ.csv, number of users = 20
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GFED.csv, number of users = 49
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AIRT.csv, number of users = 190
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SITC.csv, number of users = 797
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NXN.csv, number of users = 21
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BNY.csv, number of users = 50
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXU.csv, number of users = 8429
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PPA.csv, number of users = 1329
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RHE.csv, number of users = 1430
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ISSC.csv, number of users = 192
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KNDI.csv, number of users = 25212
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EFT.csv, number of users = 393
# .
# ticker: ../data/rawdata_robin_all/popularity_export/USTB.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TRNS.csv, number of users = 70
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/XSHD.csv, number of users = 232
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBSA.csv, number of users = 26
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BCI.csv, number of users = 71
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CARO.csv, number of users = 28
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBRE.csv, number of users = 112
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AEIS.csv, number of users = 263
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UAL.csv, number of users = 311457
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TROW.csv, number of users = 1994
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ISRG.csv, number of users = 6414
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EGP.csv, number of users = 112
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TRND.csv, number of users = 8
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QDIV.csv, number of users = 94
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EFC.csv, number of users = 4371
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EEX.csv, number of users = 863
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NVR.csv, number of users = 733
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DDLS.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLAX.csv, number of users = 7
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PLYM.csv, number of users = 396
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RDVY.csv, number of users = 133
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TELA.csv, number of users = 175
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EWJE.csv, number of users = 3
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FEIM.csv, number of users = 98
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WOR.csv, number of users = 340
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TLRY.csv, number of users = 102339
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PRGO.csv, number of users = 476
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LECO.csv, number of users = 205
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VONG.csv, number of users = 1417
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ALTG.csv, number of users = 278
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RPT.csv, number of users = 263
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VCYT.csv, number of users = 557
# .
# ticker: ../data/rawdata_robin_all/popularity_export/USAC.csv, number of users = 2095
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HYLB.csv, number of users = 263
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/COHN.csv, number of users = 1054
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NBW.csv, number of users = 26
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PLOW.csv, number of users = 182
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PIC.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PRGX.csv, number of users = 85
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ERF.csv, number of users = 5181
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IFN.csv, number of users = 237
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FIHD.csv, number of users = 27
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RSX.csv, number of users = 570
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PHG.csv, number of users = 812
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UVE.csv, number of users = 732
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JHMH.csv, number of users = 39
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BUD.csv, number of users = 38569
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ORRF.csv, number of users = 52
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IDHD.csv, number of users = 53
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SUSA.csv, number of users = 664
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PFL.csv, number of users = 275
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HVT.A.csv, number of users = 18
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IHE.csv, number of users = 100
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GEM.csv, number of users = 234
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GDI.csv, number of users = 155
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PDS.csv, number of users = 11943
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OESX.csv, number of users = 2067
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPLG.csv, number of users = 1063
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BLDP.csv, number of users = 10222
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SIBN.csv, number of users = 155
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NOG.csv, number of users = 57833
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SWGAY.csv, number of users = 245
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BXC.csv, number of users = 503
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SMCAY.csv, number of users = 63
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TTNDY.csv, number of users = 1425
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHAP.csv, number of users = 6010
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/KSM.csv, number of users = 44
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XCUR.csv, number of users = 866
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OVCHY.csv, number of users = 102
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DXGE.csv, number of users = 26
# .
# ticker: ../data/rawdata_robin_all/popularity_export/YLCO.csv, number of users = 738
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PDD.csv, number of users = 10757
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHCO.csv, number of users = 43
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBIO.csv, number of users = 1175
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LBTYK.csv, number of users = 427
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMAB.csv, number of users = 682
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NFRA.csv, number of users = 44
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPOK.csv, number of users = 83
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MXDE.csv, number of users = 8
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPLP.csv, number of users = 338
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TPR.csv, number of users = 9171
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TSI.csv, number of users = 77
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CSS.csv, number of users = 145
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DVN.csv, number of users = 11526
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MGEE.csv, number of users = 228
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FJUL.csv, number of users = 2
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AMSC.csv, number of users = 1023
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SVT.csv, number of users = 79
# .
# ticker: ../data/rawdata_robin_all/popularity_export/STK.csv, number of users = 323
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XLRN.csv, number of users = 456
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SCYX.csv, number of users = 8349
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AIH.csv, number of users = 131
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MN.csv, number of users = 311
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LOVE.csv, number of users = 3866
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ASYS.csv, number of users = 521
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VIR.csv, number of users = 8964
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CSD.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GNRS.csv, number of users = 8
# .
# ticker: ../data/rawdata_robin_all/popularity_export/INSE.csv, number of users = 1301
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BSEP.csv, number of users = 2
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SVC.csv, number of users = 3839
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DVY.csv, number of users = 3146
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FMF.csv, number of users = 9
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DTF.csv, number of users = 63
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/ESGF.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HAFC.csv, number of users = 251
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BTAI.csv, number of users = 4027
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VIE.csv, number of users = 969
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CR.csv, number of users = 451
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AGT.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MUTE.csv, number of users = 60
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DPHC.csv, number of users = 20884
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ADTN.csv, number of users = 765
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EQRR.csv, number of users = 10
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BFRA.csv, number of users = 7289
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JVA.csv, number of users = 2859
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SAND.csv, number of users = 7348
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DXR.csv, number of users = 163
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JNCE.csv, number of users = 662
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SOCL.csv, number of users = 965
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HSTO.csv, number of users = 1845
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CEQP.csv, number of users = 10772
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RLAY.csv, number of users = 892
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/OFLX.csv, number of users = 43
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IBHB.csv, number of users = 9
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DRRX.csv, number of users = 4661
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HAIL.csv, number of users = 237
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BV.csv, number of users = 443
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MNCL.csv, number of users = 146
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AM.csv, number of users = 30029
# .
# ticker: ../data/rawdata_robin_all/popularity_export/W.csv, number of users = 10037
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GLEO.csv, number of users = 31
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DRSK.csv, number of users = 17
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ADX.csv, number of users = 554
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MQT.csv, number of users = 34
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/CE.csv, number of users = 279
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ASTC.csv, number of users = 1746
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MRO.csv, number of users = 187314
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DZZ.csv, number of users = 275
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HOV.csv, number of users = 355
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NBIX.csv, number of users = 1709
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RWVG.csv, number of users = 8
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EVTC.csv, number of users = 176
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OCSI.csv, number of users = 249
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VYGR.csv, number of users = 1684
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HMI.csv, number of users = 1752
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BA.csv, number of users = 320552
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VRTX.csv, number of users = 4548
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AFG.csv, number of users = 323
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UBOT.csv, number of users = 1181
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GVDNY.csv, number of users = 117
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BRK.B.csv, number of users = 102560
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SSPK.csv, number of users = 2316
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JPHF.csv, number of users = 29
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FCPI.csv, number of users = 11
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GGAL.csv, number of users = 442
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SNR.csv, number of users = 2998
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GILD.csv, number of users = 88730
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DMS.csv, number of users = 229
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FVL.csv, number of users = 7
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SHSP.csv, number of users = 433
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WW.csv, number of users = 2081
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHN.csv, number of users = 39
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/TIP.csv, number of users = 781
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VQT.csv, number of users = 11
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LACK.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AQN.csv, number of users = 2950
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MDB.csv, number of users = 10066
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MGY.csv, number of users = 2027
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DOL.csv, number of users = 41
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SMLV.csv, number of users = 29
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FTS.csv, number of users = 972
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EVBN.csv, number of users = 224
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SLM.csv, number of users = 3492
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FSCT.csv, number of users = 701
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SNE.csv, number of users = 110422
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NLSN.csv, number of users = 1624
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AMKR.csv, number of users = 896
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VPG.csv, number of users = 79
# .
# ticker: ../data/rawdata_robin_all/popularity_export/THC.csv, number of users = 1413
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FCFS.csv, number of users = 151
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/LOOP.csv, number of users = 1219
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHY.csv, number of users = 433
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARB.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TAYD.csv, number of users = 31
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TOTL.csv, number of users = 82
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MDU.csv, number of users = 690
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/CREX.csv, number of users = 2145
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DBMF.csv, number of users = 5
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RBUS.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FYT.csv, number of users = 31
# .
# ticker: ../data/rawdata_robin_all/popularity_export/STLC.csv, number of users = 2
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ACIU.csv, number of users = 2387
# .
# ticker: ../data/rawdata_robin_all/popularity_export/INDL.csv, number of users = 1245
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XELA.csv, number of users = 18802
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TDW.csv, number of users = 432
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TATT.csv, number of users = 314
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WSTG.csv, number of users = 128
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MIE.csv, number of users = 826
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CEI.csv, number of users = 54745
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CFR.csv, number of users = 499
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XSD.csv, number of users = 699
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ESPO.csv, number of users = 5008
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SCU.csv, number of users = 96
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PFMT.csv, number of users = 449
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DCO.csv, number of users = 312
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FXP.csv, number of users = 45
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FYC.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SOYB.csv, number of users = 495
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VRNA.csv, number of users = 1362
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CNXT.csv, number of users = 139
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CGA.csv, number of users = 359
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TVTY.csv, number of users = 2268
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EQIX.csv, number of users = 3264
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XPH.csv, number of users = 514
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ESSC.csv, number of users = 16
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ZG.csv, number of users = 3384
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DGRW.csv, number of users = 1116
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HVT.csv, number of users = 134
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FXG.csv, number of users = 38
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/STMP.csv, number of users = 2675
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FDNI.csv, number of users = 175
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OCPNY.csv, number of users = 724
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PFNX.csv, number of users = 1691
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DUOT.csv, number of users = 142
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IUSS.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MKL.csv, number of users = 1177
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GURE.csv, number of users = 238
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QUIK.csv, number of users = 1147
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OSH.csv, number of users = 502
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SCC.csv, number of users = 55
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HUN.csv, number of users = 1178
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FXF.csv, number of users = 149
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KALL.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSTX.csv, number of users = 282
# .
# ticker: ../data/rawdata_robin_all/popularity_export/STON.csv, number of users = 4162
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VIXM.csv, number of users = 235
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MBOT.csv, number of users = 1894
# .
# ticker: ../data/rawdata_robin_all/popularity_export/INFR.csv, number of users = 27
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TER.csv, number of users = 4686
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CULP.csv, number of users = 147
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HARP.csv, number of users = 2690
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TFI.csv, number of users = 237
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PCPL.csv, number of users = 25
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MLCO.csv, number of users = 2403
# .
# ticker: ../data/rawdata_robin_all/popularity_export/YJ.csv, number of users = 1136
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PHCF.csv, number of users = 260
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HDMV.csv, number of users = 18
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SMBK.csv, number of users = 75
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EAOR.csv, number of users = 1
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JOB.csv, number of users = 2260
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GPMT.csv, number of users = 4213
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CGW.csv, number of users = 2047
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MID.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CDL.csv, number of users = 70
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VRML.csv, number of users = 6244
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TDV.csv, number of users = 82
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TZAC.csv, number of users = 31
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PODD.csv, number of users = 858
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TIF.csv, number of users = 1106
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MDT.csv, number of users = 12099
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARC.csv, number of users = 1440
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ATGE.csv, number of users = 150
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IPAR.csv, number of users = 197
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DLA.csv, number of users = 382
# .
# ticker: ../data/rawdata_robin_all/popularity_export/STAR.csv, number of users = 417
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SZNE.csv, number of users = 25
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SND.csv, number of users = 1699
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AXSM.csv, number of users = 3241
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SMMD.csv, number of users = 153
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HSBC.csv, number of users = 3946
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EJPRY.csv, number of users = 772
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHX.csv, number of users = 1019
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ASG.csv, number of users = 1730
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NEXA.csv, number of users = 264
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/CIK.csv, number of users = 915
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BOOT.csv, number of users = 1168
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MDC.csv, number of users = 330
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UI.csv, number of users = 1037
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BCYC.csv, number of users = 856
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AMSWA.csv, number of users = 679
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PAGP.csv, number of users = 1135
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XITK.csv, number of users = 207
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FORM.csv, number of users = 568
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KOMP.csv, number of users = 186
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FTR.csv, number of users = 10196
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/FUV.csv, number of users = 15395
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DNI.csv, number of users = 269
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SMH.csv, number of users = 3360
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MEG.csv, number of users = 308
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TM.csv, number of users = 9218
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DXD.csv, number of users = 657
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CPIX.csv, number of users = 259
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FTSI.csv, number of users = 1895
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DESP.csv, number of users = 354
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VDC.csv, number of users = 1121
# .
# ticker: ../data/rawdata_robin_all/popularity_export/V.csv, number of users = 98269
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ADTX.csv, number of users = 1795
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/JWS.csv, number of users = 176
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QRVO.csv, number of users = 4131
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FAD.csv, number of users = 16
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CIEN.csv, number of users = 3304
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SALM.csv, number of users = 3447
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SXI.csv, number of users = 58
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GEOS.csv, number of users = 166
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IRMD.csv, number of users = 183
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSMM.csv, number of users = 25
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AL.csv, number of users = 3471
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BW.csv, number of users = 1187
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IBHC.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/A.csv, number of users = 1642
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/REKR.csv, number of users = 5248
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EDIV.csv, number of users = 114
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CS.csv, number of users = 1699
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CEPU.csv, number of users = 641
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FAS.csv, number of users = 6959
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ATRS.csv, number of users = 3804
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QAI.csv, number of users = 68
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLC.csv, number of users = 108
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HBP.csv, number of users = 1429
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FOX.csv, number of users = 1158
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RISN.csv, number of users = 5
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MX.csv, number of users = 287
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NC.csv, number of users = 258
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ESGG.csv, number of users = 28
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DUC.csv, number of users = 64
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSCF.csv, number of users = 26
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLT.csv, number of users = 312
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VIS.csv, number of users = 491
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HMSY.csv, number of users = 1504
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MO.csv, number of users = 30501
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CPI.csv, number of users = 19
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LK.csv, number of users = 120372
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AMPY.csv, number of users = 3600
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/HFBL.csv, number of users = 25
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QMJ.csv, number of users = 7
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SUN.csv, number of users = 6467
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FNK.csv, number of users = 10
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AVEO.csv, number of users = 4380
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HCC.csv, number of users = 728
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BIZD.csv, number of users = 329
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BRLI.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/USMV.csv, number of users = 1485
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IDIV.csv, number of users = 210
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ICLK.csv, number of users = 568
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMAC.csv, number of users = 1552
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WBC.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/COFS.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MCRI.csv, number of users = 595
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBIN.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EKAR.csv, number of users = 105
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SGMO.csv, number of users = 6040
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WCG.csv, number of users = 173
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CTRA.csv, number of users = 912
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SWKS.csv, number of users = 12084
# .
# ticker: ../data/rawdata_robin_all/popularity_export/USOI.csv, number of users = 4193
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHAQ.csv, number of users = 7
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FRPT.csv, number of users = 1487
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ALYA.csv, number of users = 770
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ZGNX.csv, number of users = 1787
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RCKT.csv, number of users = 1830
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UCHF.csv, number of users = 17
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WBT.csv, number of users = 3285
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KRMA.csv, number of users = 253
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPMB.csv, number of users = 55
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TBPH.csv, number of users = 357
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UCIB.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NMY.csv, number of users = 32
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PPSI.csv, number of users = 415
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MFNC.csv, number of users = 94
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GEL.csv, number of users = 6755
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IHD.csv, number of users = 131
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FRSX.csv, number of users = 11039
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LPTH.csv, number of users = 4921
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PFM.csv, number of users = 89
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VCTR.csv, number of users = 314
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/USAU.csv, number of users = 2164
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LEAF.csv, number of users = 844
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PREF.csv, number of users = 46
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ENPH.csv, number of users = 34395
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NCR.csv, number of users = 1327
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JHMI.csv, number of users = 11
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ITCI.csv, number of users = 3250
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KRBN.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GMOM.csv, number of users = 34
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HWCC.csv, number of users = 324
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BWZ.csv, number of users = 22
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BTA.csv, number of users = 60
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KNSA.csv, number of users = 1220
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BEAT.csv, number of users = 1123
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GIX.csv, number of users = 62
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MHLD.csv, number of users = 774
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/IEC.csv, number of users = 1127
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NOVA.csv, number of users = 16596
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OIIM.csv, number of users = 1287
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LYRA.csv, number of users = 136
# .
# ticker: ../data/rawdata_robin_all/popularity_export/APEI.csv, number of users = 286
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NAZ.csv, number of users = 32
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WLH.csv, number of users = 93
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PBBI.csv, number of users = 20
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UTL.csv, number of users = 63
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/NXTD.csv, number of users = 17763
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CFCV.csv, number of users = 20
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MARK.csv, number of users = 43612
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UBA.csv, number of users = 659
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BPOP.csv, number of users = 1483
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NOAH.csv, number of users = 256
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IQIN.csv, number of users = 1
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SLGG.csv, number of users = 4983
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EGF.csv, number of users = 32
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XTNT.csv, number of users = 1400
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ENFR.csv, number of users = 63
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EYES.csv, number of users = 2685
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PGHY.csv, number of users = 96
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ALCO.csv, number of users = 65
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TRNE.csv, number of users = 109
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ICUI.csv, number of users = 168
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPUS.csv, number of users = 224
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SIXA.csv, number of users = 8
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NVS.csv, number of users = 4745
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ZBIO.csv, number of users = 54
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MCHP.csv, number of users = 4365
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PBTS.csv, number of users = 118
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBL.csv, number of users = 469
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CDNS.csv, number of users = 2372
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TROV.csv, number of users = 2202
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DNZOY.csv, number of users = 413
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VCLT.csv, number of users = 977
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BPMX.csv, number of users = 27514
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KURE.csv, number of users = 358
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NVMI.csv, number of users = 234
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EFU.csv, number of users = 2
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BKRKY.csv, number of users = 285
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BCH.csv, number of users = 138
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARKW.csv, number of users = 9583
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FUNC.csv, number of users = 88
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CMDY.csv, number of users = 10
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KRYS.csv, number of users = 877
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MTEM.csv, number of users = 1024
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UNB.csv, number of users = 130
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXT.csv, number of users = 54
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HYTR.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VSGX.csv, number of users = 277
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CORV.csv, number of users = 8421
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GHII.csv, number of users = 58
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARDX.csv, number of users = 1399
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMTB.csv, number of users = 30
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BNO.csv, number of users = 5192
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXC.csv, number of users = 490
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TUES.csv, number of users = 7312
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PTVCA.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSL.csv, number of users = 25
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RHS.csv, number of users = 52
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EHI.csv, number of users = 134
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GSV.csv, number of users = 3014
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GPM.csv, number of users = 287
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EIM.csv, number of users = 91
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LIND.csv, number of users = 820
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BILI.csv, number of users = 40100
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SGSOY.csv, number of users = 69
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DTEA.csv, number of users = 5838
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPYG.csv, number of users = 20787
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AEGN.csv, number of users = 109
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/SRAC.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IVAC.csv, number of users = 388
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LBC.csv, number of users = 64
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARGT.csv, number of users = 197
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FWONK.csv, number of users = 961
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PSN.csv, number of users = 586
# .
# ticker: ../data/rawdata_robin_all/popularity_export/XMMO.csv, number of users = 130
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLNT.csv, number of users = 1298
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MTEX.csv, number of users = 82
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LAZ.csv, number of users = 883
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CCEP.csv, number of users = 1010
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MMIN.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WWW.csv, number of users = 706
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ULH.csv, number of users = 140
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DTEC.csv, number of users = 247
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RJN.csv, number of users = 408
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WLTW.csv, number of users = 211
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/ABCB.csv, number of users = 726
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MSCI.csv, number of users = 1282
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IFEU.csv, number of users = 32
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GSC.csv, number of users = 42
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GPX.csv, number of users = 297
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHTR.csv, number of users = 1410
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HUBG.csv, number of users = 169
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LCR.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CORT.csv, number of users = 1122
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BMA.csv, number of users = 499
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VSDA.csv, number of users = 194
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ORGS.csv, number of users = 281
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXV.csv, number of users = 35
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLMX.csv, number of users = 23
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PNOV.csv, number of users = 5
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MTGP.csv, number of users = 3
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BLE.csv, number of users = 73
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MORF.csv, number of users = 175
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EIX.csv, number of users = 1562
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/KDP.csv, number of users = 6146
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HIPS.csv, number of users = 220
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RGI.csv, number of users = 69
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OUNZ.csv, number of users = 973
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EGOV.csv, number of users = 222
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBN.csv, number of users = 276
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CASH.csv, number of users = 492
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UBT.csv, number of users = 71
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AGRO.csv, number of users = 1549
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EPOL.csv, number of users = 198
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LBRT.csv, number of users = 2740
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NSPR.csv, number of users = 9606
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LNDC.csv, number of users = 418
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KBCSY.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DARE.csv, number of users = 3899
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LGLV.csv, number of users = 112
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RFM.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TRMK.csv, number of users = 67
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CSLT.csv, number of users = 4662
# .
# ticker: ../data/rawdata_robin_all/popularity_export/REV.csv, number of users = 2626
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AGRX.csv, number of users = 20011
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBY.csv, number of users = 8235
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BAB.csv, number of users = 187
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NTN.csv, number of users = 5488
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CLPHY.csv, number of users = 254
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BYFC.csv, number of users = 14709
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BNSO.csv, number of users = 182
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMMU.csv, number of users = 7233
# .
# ...
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FTI.csv, number of users = 3233
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AOSL.csv, number of users = 715
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CRDF.csv, number of users = 551
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TOUR.csv, number of users = 851
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TA.csv, number of users = 718
# .
# ticker: ../data/rawdata_robin_all/popularity_export/APG.csv, number of users = 468
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MLND.csv, number of users = 6364
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CKX.csv, number of users = 18
# .
# ticker: ../data/rawdata_robin_all/popularity_export/THY.csv, number of users = 1
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CIG.csv, number of users = 7897
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UE.csv, number of users = 220
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IGBH.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AMJL.csv, number of users = 906
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NEOS.csv, number of users = 1152
# .
# ticker: ../data/rawdata_robin_all/popularity_export/Z.csv, number of users = 8542
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VGT.csv, number of users = 23263
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AGN.csv, number of users = 1261
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TCTL.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MQY.csv, number of users = 37
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MERC.csv, number of users = 895
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GRNV.csv, number of users = 65
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JTD.csv, number of users = 150
# .
# ticker: ../data/rawdata_robin_all/popularity_export/STWD.csv, number of users = 18113
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SOMLY.csv, number of users = 144
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SYV.csv, number of users = 1
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IEME.csv, number of users = 133
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/VRTU.csv, number of users = 791
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BL.csv, number of users = 1238
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IBKC.csv, number of users = 201
# .
# ticker: ../data/rawdata_robin_all/popularity_export/VIAC.csv, number of users = 20695
# .
# ticker: ../data/rawdata_robin_all/popularity_export/M.csv, number of users = 67336
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HOFV.csv, number of users = 2584
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AFLG.csv, number of users = 3
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BSJR.csv, number of users = 3
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PHYS.csv, number of users = 1982
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ACRE.csv, number of users = 1464
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RBNC.csv, number of users = 110
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NWPX.csv, number of users = 120
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ETNB.csv, number of users = 468
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AFMC.csv, number of users = 1
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AEF.csv, number of users = 79
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OSTK.csv, number of users = 20385
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LMAT.csv, number of users = 311
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EDEN.csv, number of users = 81
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TPH.csv, number of users = 361
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GBGR.csv, number of users = 5
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NBEV.csv, number of users = 59365
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FMK.csv, number of users = 3
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DUO.csv, number of users = 5747
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLO.csv, number of users = 1776
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AIR.csv, number of users = 5654
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MT.csv, number of users = 2642
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CRM.csv, number of users = 53002
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/XES.csv, number of users = 605
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SSDOY.csv, number of users = 367
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CPE.csv, number of users = 106509
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CLWT.csv, number of users = 336
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WTER.csv, number of users = 10929
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SUB.csv, number of users = 43
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RYTM.csv, number of users = 257
# .
# ticker: ../data/rawdata_robin_all/popularity_export/URGN.csv, number of users = 549
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PDBC.csv, number of users = 349
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SOLY.csv, number of users = 1367
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HAP.csv, number of users = 9
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NX.csv, number of users = 147
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MC.csv, number of users = 438
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LMNL.csv, number of users = 3579
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IBDL.csv, number of users = 38
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/CTRM.csv, number of users = 15761
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PUMP.csv, number of users = 5668
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NNY.csv, number of users = 30
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GFL.csv, number of users = 1317
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HERO.csv, number of users = 2407
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ONCS.csv, number of users = 951
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PDI.csv, number of users = 982
# .
# ticker: ../data/rawdata_robin_all/popularity_export/USNA.csv, number of users = 270
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PGR.csv, number of users = 2264
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ELGX.csv, number of users = 3001
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SNDR.csv, number of users = 549
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GDS.csv, number of users = 624
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SUHJY.csv, number of users = 1287
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EELV.csv, number of users = 37
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/BZQ.csv, number of users = 245
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WAT.csv, number of users = 198
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SRTY.csv, number of users = 1884
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NNN.csv, number of users = 2491
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NAVB.csv, number of users = 1241
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SWKH.csv, number of users = 22
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QFIN.csv, number of users = 932
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SUSL.csv, number of users = 122
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PEZ.csv, number of users = 30
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GSIE.csv, number of users = 168
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RARX.csv, number of users = 722
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SNDE.csv, number of users = 2036
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TPLC.csv, number of users = 242
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UYG.csv, number of users = 147
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMAX.csv, number of users = 10551
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KAOOY.csv, number of users = 305
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IMOS.csv, number of users = 132
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EUDV.csv, number of users = 17
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PIN.csv, number of users = 248
# .
# ticker: ../data/rawdata_robin_all/popularity_export/WUBA.csv, number of users = 421
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CFBI.csv, number of users = 6
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IEX.csv, number of users = 304
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AGFS.csv, number of users = 6387
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPCE.csv, number of users = 156590
# .
# ticker: ../data/rawdata_robin_all/popularity_export/HWBK.csv, number of users = 54
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CMRX.csv, number of users = 852
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JHME.csv, number of users = 82
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BUI.csv, number of users = 142
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BTZ.csv, number of users = 200
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBGI.csv, number of users = 816
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NAV.csv, number of users = 727
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BWA.csv, number of users = 1545
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LIVN.csv, number of users = 283
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QQEW.csv, number of users = 174
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHNR.csv, number of users = 906
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JAGX.csv, number of users = 14207
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CHMI.csv, number of users = 1058
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LRCX.csv, number of users = 6475
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IEO.csv, number of users = 560
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BKMC.csv, number of users = 4
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EPC.csv, number of users = 380
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GHG.csv, number of users = 891
# .
# ticker: ../data/rawdata_robin_all/popularity_export/YCS.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PLMR.csv, number of users = 1037
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ICCH.csv, number of users = 29
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BPMC.csv, number of users = 1318
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QQQE.csv, number of users = 760
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PRSP.csv, number of users = 378
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MKC.V.csv, number of users = 100
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BCS.csv, number of users = 7601
# .
# ticker: ../data/rawdata_robin_all/popularity_export/APPS.csv, number of users = 19723
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UCI.csv, number of users = 14
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KRTX.csv, number of users = 1107
# .
# ticker: ../data/rawdata_robin_all/popularity_export/FLAU.csv, number of users = 19
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BAL.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/DJCI.csv, number of users = 16
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BBW.csv, number of users = 3191
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RDVT.csv, number of users = 408
# .
# ticker: ../data/rawdata_robin_all/popularity_export/TELL.csv, number of users = 37402
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RGP.csv, number of users = 132
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EURL.csv, number of users = 146
# .
# ticker: ../data/rawdata_robin_all/popularity_export/RODM.csv, number of users = 19
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EEB.csv, number of users = 12
# .
# ticker: ../data/rawdata_robin_all/popularity_export/REX.csv, number of users = 52
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PLXS.csv, number of users = 144
# .
# ticker: ../data/rawdata_robin_all/popularity_export/YVR.csv, number of users = 2589
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AKER.csv, number of users = 3953
# .
# ticker: ../data/rawdata_robin_all/popularity_export/JQUA.csv, number of users = 20
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BCD.csv, number of users = 9
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NUS.csv, number of users = 991
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SIZE.csv, number of users = 33
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NWL.csv, number of users = 5226
# .
# ticker: ../data/rawdata_robin_all/popularity_export/QTNT.csv, number of users = 493
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UAA.csv, number of users = 33045
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPTL.csv, number of users = 416
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/IHDG.csv, number of users = 67
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KIN.csv, number of users = 2074
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SBIO.csv, number of users = 324
# .
# ticker: ../data/rawdata_robin_all/popularity_export/EDF.csv, number of users = 1083
# .
# ticker: ../data/rawdata_robin_all/popularity_export/IQDE.csv, number of users = 24
# .
# ticker: ../data/rawdata_robin_all/popularity_export/KWEB.csv, number of users = 1675
# .
# ticker: ../data/rawdata_robin_all/popularity_export/AKO.B.csv, number of users = 37
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SRAX.csv, number of users = 448
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NSRGY.csv, number of users = 3426
# .
# ticker: ../data/rawdata_robin_all/popularity_export/LAC.csv, number of users = 9732
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARGO.csv, number of users = 228
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BLK.csv, number of users = 5669
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BMO.csv, number of users = 4489
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NXC.csv, number of users = 15
# .
# ticker: ../data/rawdata_robin_all/popularity_export/UXIN.csv, number of users = 5052
# .
# ticker: ../data/rawdata_robin_all/popularity_export/SPXX.csv, number of users = 290
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OLLI.csv, number of users = 2531
# .
# ticker: ../data/rawdata_robin_all/popularity_export/PPL.csv, number of users = 7067
# .
# ticker: ../data/rawdata_robin_all/popularity_export/GSM.csv, number of users = 4100
# .
# ticker: ../data/rawdata_robin_all/popularity_export/NVCN.csv, number of users = 1860
# .
# ticker: ../data/rawdata_robin_all/popularity_export/OBCI.csv, number of users = 833
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ROKU.csv, number of users = 51301
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARDC.csv, number of users = 163
# .
# ticker: ../data/rawdata_robin_all/popularity_export/ARGX.csv, number of users = 428
# .
# ticker: ../data/rawdata_robin_all/popularity_export/CABGY.csv, number of users = 345
# .
# ticker: ../data/rawdata_robin_all/popularity_export/MTDR.csv, number of users = 11669
# .
# ticker: ../data/rawdata_robin_all/popularity_export/BWEN.csv, number of users = 1006
# ..
# ticker: ../data/rawdata_robin_all/popularity_export/KEM.csv, number of users = 1285
#
#
# end of dir loop
#
#  total number of csv files (tickers) = 8597

# %%
df_popularity.describe()
# Out:
#                users
# count    8327.000000
# mean     5350.564069
# std     31072.938649
# min         1.000000
# 25%        81.500000
# 50%       408.000000
# 75%      1861.500000
# max    911470.000000

# %%
df_popularity.sort_values('users', axis=0, ascending=True, inplace=False)
# Out:
#      ticker     users
# 6145   QLVD       1.0
# 1652   RODE       1.0
# 2283   BSMO       1.0
# 2614   TEGS       1.0
# 281    EAOR       1.0
# 4847   UMAY       1.0
# 1625   FLMI       1.0
# 3127   TREB       1.0
# 5379   LSAF       1.0
# 3441   SMDY       1.0
# 6399   TUSA       1.0
# 2887   FMAY       1.0
# 5732   USEQ       1.0
# 2863   RGLB       1.0
# 2489   BSCE       1.0
# 2795   BSML       1.0
# 862    RWUI       1.0
# 3035   IMFP       1.0
# 6722    EEP       1.0
# 2540   DTYL       1.0
# 5706   FLSP       1.0
# 3689   NJUL       1.0
# 1227   HCRB       1.0
# 7901   SIXL       1.0
# 8166    SYV       1.0
# 5055   AMNA       1.0
# 8150    THY       1.0
# 8002   MRSK       1.0
# 4047   RWSL       1.0
# 4414   EJAN       1.0
# ...     ...       ...
# 6227    RCL  221033.0
# 4718   TWTR  232223.0
# 763     CGC  233290.0
# 5211   NFLX  236819.0
# 3280   UBER  248559.0
# 6194   HEXO  249204.0
# 4561     FB  254208.0
# 7069   BABA  255110.0
# 3560    AMD  264849.0
# 5125    NIO  268353.0
# 40      UAL  311457.0
# 178      BA  320552.0
# 5634    FIT  323346.0
# 5508   MRNA  339461.0
# 2211   SNAP  350278.0
# 7180   NCLH  353071.0
# 989     BAC  359999.0
# 6279   PLUG  387421.0
# 2439   AMZN  427973.0
# 4916    ACB  430303.0
# 5943   GPRO  475051.0
# 3409    CCL  481631.0
# 5536   TSLA  563621.0
# 7048    DAL  572679.0
# 5032    DIS  598367.0
# 5949    AAL  637705.0
# 3157   MSFT  653838.0
# 7576   AAPL  730774.0
# 5065     GE  856899.0
# 1252      F  911470.0
#
# [8327 rows x 2 columns]

# %%
users_low_end = 500000
users_high_end = 1000000

df_popularity_select = df_popularity[(df_popularity["users"] > users_low_end) & (df_popularity["users"] < users_high_end)]
df_popularity_select.sort_values('users', axis=0, ascending=True, inplace=True)
df_popularity_select
# Out:
#      ticker     users
# 5536   TSLA  563621.0
# 7048    DAL  572679.0
# 5032    DIS  598367.0
# 5949    AAL  637705.0
# 3157   MSFT  653838.0
# 7576   AAPL  730774.0
# 5065     GE  856899.0
# 1252      F  911470.0

# %%
df_popularity_select.hvplot(x='ticker', y='users', width=700, height=400, kind='bar')
# Out:
# :Bars   [ticker]   (users)

# %%
# export top ticks  to csv
df_popularity_select.to_csv(r'../data/cleandata/Processed_Data/df_popularity.csv', index = False)
